# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../input/churn-predictions-personal/Churn_Predictions.csv')
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0          2       0.00              1          1               1
# 1          1   83807.86              1          0               1
# 2          8  159660.80              3          1               0
# 3          1       0.00              2          0               0
# 4          2  125510.82              1          1               1
# ...      ...        ...            ...        ...             ...
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 0           101348.88       1
# 1           112542.58       0
# 2           113931.57       1
# 3            93826.63       0
# 4            79084.10       0
# ...               ...     ...
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0
#
# [10000 rows x 14 columns]

# %%
df.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
# 5       8  113755.78              2          1               0
# 6       7       0.00              2          1               1
# 7       4  115046.74              4          1               0
# 8       4  142051.07              2          0               1
# 9       2  134603.88              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0
# 5        149756.71       1
# 6         10062.80       0
# 7        119346.88       1
# 8         74940.50       0
# 9         71725.73       0

# %%
df.tail(10)
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 9990       9991    15798964   Nkemakonam          714   Germany    Male   33
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
# 9992       9993    15657105  Chukwualuka          726     Spain    Male   36
# 9993       9994    15569266       Rahman          644    France    Male   28
# 9994       9995    15719294         Wood          800    France  Female   29
# 9995       9996    15606229     Obijiaku          771    France    Male   39
# 9996       9997    15569892    Johnstone          516    France    Male   35
# 9997       9998    15584532          Liu          709    France  Female   36
# 9998       9999    15682355    Sabbatini          772   Germany    Male   42
# 9999      10000    15628319       Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9990       3   35016.60              1          1               0
# 9991       4   88381.21              1          1               0
# 9992       2       0.00              1          1               0
# 9993       7  155060.41              1          1               0
# 9994       2       0.00              2          0               0
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9990         53667.08       0
# 9991         69384.71       1
# 9992        195192.40       0
# 9993         29179.52       0
# 9994        167773.55       0
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %%
df.sample(10)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 5216       5217    15671104   Aksakova          637     Spain    Male   43
# 9215       9216    15624180   Genovesi          584   Germany  Female   37
# 8700       8701    15627637     Obioma          709   Germany    Male   23
# 2110       2111    15795990   Lumholtz          722   Germany  Female   48
# 5011       5012    15609011      Barry          480     Spain    Male   47
# 55           56    15760861  Phillipps          619    France    Male   43
# 3134       3135    15660541  Olisanugo          694    France    Male   34
# 8051       8052    15697801   Sokolova          605   Germany  Female   56
# 8054       8055    15686236  Trevisani          525   Germany  Female   47
# 6304       6305    15653455      Smith          648    France  Female   38
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 5216       3  172196.23              1          1               1
# 9215      10  134171.80              4          1               1
# 8700       8   73314.04              2          1               0
# 2110      10  138311.76              1          1               1
# 5011       8   75408.33              1          1               0
# 55         1  125211.92              1          1               1
# 3134       5  127900.03              1          1               0
# 8051       1   74129.18              2          1               1
# 8054       1  118087.68              1          1               0
# 6304       2       0.00              2          0               1
#
#       EstimatedSalary  Exited
# 5216        104769.96       0
# 9215         70927.11       1
# 8700         63446.47       0
# 2110          3472.63       1
# 5011         25887.89       1
# 55          113410.49       0
# 3134        101737.80       0
# 8051         62199.78       1
# 8054         88120.78       1
# 6304          9551.49       0

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df= df.apply(lambda x: x.astype(float) if x.dtype=="int64" else x)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  float64
#  1   CustomerId       10000 non-null  float64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  float64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  float64
#  7   Tenure           10000 non-null  float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  float64
#  10  HasCrCard        10000 non-null  float64
#  11  IsActiveMember   10000 non-null  float64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  float64
# dtypes: float64(11), object(3)
# memory usage: 1.1+ MB

# %%
df.drop(["RowNumber", "CustomerId", "Surname"], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_16/1280138418.py in <module>
# ----> 1 df.drop(["RowNumber", "CustomerId", "Surname"], axis=1, inplace=True)
#
# /opt/conda/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# /opt/conda/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['RowNumber' 'CustomerId' 'Surname'] not found in axis"

# %%
df.head(3)
# Out:
#    CreditScore Geography  Gender   Age  Tenure    Balance  NumOfProducts  \
# 0        619.0    France  Female  42.0     2.0       0.00            1.0
# 1        608.0     Spain  Female  41.0     1.0   83807.86            1.0
# 2        502.0    France  Female  42.0     8.0  159660.80            3.0
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0        1.0             1.0        101348.88     1.0
# 1        0.0             1.0        112542.58     0.0
# 2        1.0             0.0        113931.57     1.0

# %%
pd.options.display.float_format = '{:}'.format

# %%
df.head(3)
# Out:
#    CreditScore Geography  Gender   Age  Tenure    Balance  NumOfProducts  \
# 0        619.0    France  Female  42.0     2.0       0.00            1.0
# 1        608.0     Spain  Female  41.0     1.0   83807.86            1.0
# 2        502.0    France  Female  42.0     8.0  159660.80            3.0
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0        1.0             1.0        101348.88     1.0
# 1        0.0             1.0        112542.58     0.0
# 2        1.0             0.0        113931.57     1.0

# %%
df.describe().T
# Out:
#                    count           mean           std     min       25%  \
# CreditScore      10000.0     650.528800     96.653299  350.00    584.00
# Age              10000.0      38.921800     10.487806   18.00     32.00
# Tenure           10000.0       5.012800      2.892174    0.00      3.00
# Balance          10000.0   76485.889288  62397.405202    0.00      0.00
# NumOfProducts    10000.0       1.530200      0.581654    1.00      1.00
# HasCrCard        10000.0       0.705500      0.455840    0.00      0.00
# IsActiveMember   10000.0       0.515100      0.499797    0.00      0.00
# EstimatedSalary  10000.0  100090.239881  57510.492818   11.58  51002.11
# Exited           10000.0       0.203700      0.402769    0.00      0.00
#
#                         50%          75%        max
# CreditScore         652.000     718.0000     850.00
# Age                  37.000      44.0000      92.00
# Tenure                5.000       7.0000      10.00
# Balance           97198.540  127644.2400  250898.09
# NumOfProducts         1.000       2.0000       4.00
# HasCrCard             1.000       1.0000       1.00
# IsActiveMember        1.000       1.0000       1.00
# EstimatedSalary  100193.915  149388.2475  199992.48
# Exited                0.000       0.0000       1.00

# %%
df.describe(include=object).T
# Out:
#            count unique     top  freq
# Geography  10000      3  France  5014
# Gender     10000      2    Male  5457

# %%
df.nunique()
# Out:
# CreditScore         460
# Geography             3
# Gender                2
# Age                  70
# Tenure               11
# Balance            6382
# NumOfProducts         4
# HasCrCard             2
# IsActiveMember        2
# EstimatedSalary    9999
# Exited                2
# dtype: int64

# %%
df.duplicated().value_counts()
# Out:
# False    10000
# dtype: int64

# %%
df.shape
# Out:
# (10000, 11)

# %%
df.isnull().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df['Exited'].value_counts()
# Out:
# 0.0    7963
# 1.0    2037
# Name: Exited, dtype: int64

# %%
y = df['Exited']
explode = [0, 0.1]

df['Exited'].value_counts().plot(kind='pie', 
                                 autopct='%1.1f%%', 
                                 figsize=(7, 7), 
                                 explode=explode, 
                                 wedgeprops={'edgecolor': 'black'}, 
                                 shadow=True, 
                                 colors = ['purple', 'blue'], 
                                 startangle=140)
plt.title('Churn Distribution');

# %%
plt.figure(figsize=(5, 3))
df['Exited'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[df['Exited']==0].describe().T
# Out:
#                   count          mean           std     min       25%  \
# CreditScore      7963.0    651.853196     95.653837  405.00    585.00
# Age              7963.0     37.408389     10.125363   18.00     31.00
# Tenure           7963.0      5.033279      2.880658    0.00      3.00
# Balance          7963.0  72745.296779  62848.040701    0.00      0.00
# NumOfProducts    7963.0      1.544267      0.509536    1.00      1.00
# HasCrCard        7963.0      0.707146      0.455101    0.00      0.00
# IsActiveMember   7963.0      0.554565      0.497045    0.00      0.00
# EstimatedSalary  7963.0  99738.391772  57405.586966   90.07  50783.49
# Exited           7963.0      0.000000      0.000000    0.00      0.00
#
#                       50%         75%        max
# CreditScore        653.00     718.000     850.00
# Age                 36.00      41.000      92.00
# Tenure               5.00       7.000      10.00
# Balance          92072.68  126410.280  221532.80
# NumOfProducts        2.00       2.000       3.00
# HasCrCard            1.00       1.000       1.00
# IsActiveMember       1.00       1.000       1.00
# EstimatedSalary  99645.04  148609.955  199992.48
# Exited               0.00       0.000       0.00

# %%
df[df['Exited']==1].describe().T
# Out:
#                   count           mean           std     min       25%  \
# CreditScore      2037.0     645.351497    100.321503  350.00    578.00
# Age              2037.0      44.837997      9.761562   18.00     38.00
# Tenure           2037.0       4.932744      2.936106    0.00      2.00
# Balance          2037.0   91108.539337  58360.794816    0.00  38340.02
# NumOfProducts    2037.0       1.475209      0.801521    1.00      1.00
# HasCrCard        2037.0       0.699067      0.458776    0.00      0.00
# IsActiveMember   2037.0       0.360825      0.480358    0.00      0.00
# EstimatedSalary  2037.0  101465.677531  57912.418071   11.58  51907.72
# Exited           2037.0       1.000000      0.000000    1.00      1.00
#
#                        50%        75%        max
# CreditScore         646.00     716.00     850.00
# Age                  45.00      51.00      84.00
# Tenure                5.00       8.00      10.00
# Balance          109349.29  131433.33  250898.09
# NumOfProducts         1.00       2.00       4.00
# HasCrCard             1.00       1.00       1.00
# IsActiveMember        0.00       1.00       1.00
# EstimatedSalary  102460.84  152422.91  199808.10
# Exited                1.00       1.00       1.00

# %%
df['Exited'].skew()
# Out:
# 1.4716106649378211

# %%
plt.style.use('seaborn-darkgrid')

# %%
df.Geography.value_counts(normalize=True)
df.Geography.value_counts(normalize=True).plot.bar()
plt.xlabel('Geography')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df.Geography.value_counts(normalize=True)
df.Geography.value_counts(normalize=True).plot.hist()
plt.xlabel('Geography')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
df.Geography.value_counts(normalize=True)
df.Geography.value_counts(normalize=True).plot.pie()
# Out:
# <AxesSubplot:ylabel='Geography'>

# %%
plt.scatter(df['EstimatedSalary'], df['Balance'])
plt.xlabel('EstimatedSalary')
plt.ylabel('Balance')
# Out:
# Text(0, 0.5, 'Balance')

# %%
sns.pairplot(data = df, vars = ['Age', 'Balance', 'EstimatedSalary'])

# %%
df[['Age', 'Balance', 'EstimatedSalary']].corr()
# Out:
#                       Age   Balance  EstimatedSalary
# Age              1.000000  0.028308        -0.007201
# Balance          0.028308  1.000000         0.012797
# EstimatedSalary -0.007201  0.012797         1.000000

# %%
sns.heatmap(df[['Age', 'Balance', 'EstimatedSalary']].corr(), annot = True, cmap = 'Blues')
# Out:
# <AxesSubplot:>

# %%
df.groupby('Gender')['EstimatedSalary'].mean()
# Out:
# Gender
# Female    100601.541382
# Male       99664.576931
# Name: EstimatedSalary, dtype: float64

# %%
df.groupby('Gender')['EstimatedSalary'].mean()
# Out:
# Gender
# Female    100601.541382
# Male       99664.576931
# Name: EstimatedSalary, dtype: float64

# %%
sns.boxplot(df['Gender'], df['EstimatedSalary'])
# Out:
# /opt/conda/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Gender', ylabel='EstimatedSalary'>

# %%
df['Gender-Rate'] = np.where(df.Gender == 'Male', 1, 0)
df['Gender-Rate'].value_counts()
# Out:
# 1    5457
# 0    4543
# Name: Gender-Rate, dtype: int64

# %%
df.groupby('Geography')['Gender-Rate'].mean()
# Out:
# Geography
# France     0.549063
# Germany    0.524512
# Spain      0.560355
# Name: Gender-Rate, dtype: float64

# %%
df.groupby('Geography')['Gender-Rate'].mean().plot.bar()
plt.ylabel('Mean')
# Out:
# Text(0, 0.5, 'Mean')

# %%
result = pd.pivot_table(data=df, index='NumOfProducts', columns='Geography',values='Gender-Rate')
result
# Out:
# Geography        France   Germany     Spain
# NumOfProducts
# 1.0            0.556086  0.507784  0.577396
# 2.0            0.547529  0.555769  0.554522
# 3.0            0.471154  0.447917  0.378788
# 4.0            0.344828  0.416667  0.285714

# %%
sns.heatmap(result, annot=True, cmap = 'RdYlGn')
# Out:
# <AxesSubplot:xlabel='Geography', ylabel='NumOfProducts'>

# %%
plt.figure(figsize=(14, 10))
matrix = np.triu(df.corr())
sns.heatmap(df.corr(), annot=True, cmap = sns.cubehelix_palette(8), mask=matrix)
plt.xticks(rotation=45);

# %%
plt.figure(figsize = (8, 7))
df.corr()['Exited'].sort_values().drop('Exited').plot(kind = "barh");

# %%
sns.scatterplot(data=df, x='Age', y='Balance', hue='Exited')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Balance'>

# %%
df = df.drop('Gender-Rate', axis=1)

# %%
df
# Out:
#       CreditScore Geography  Gender   Age  Tenure    Balance  NumOfProducts  \
# 0           619.0    France  Female  42.0     2.0       0.00            1.0
# 1           608.0     Spain  Female  41.0     1.0   83807.86            1.0
# 2           502.0    France  Female  42.0     8.0  159660.80            3.0
# 3           699.0    France  Female  39.0     1.0       0.00            2.0
# 4           850.0     Spain  Female  43.0     2.0  125510.82            1.0
# ...           ...       ...     ...   ...     ...        ...            ...
# 9995        771.0    France    Male  39.0     5.0       0.00            2.0
# 9996        516.0    France    Male  35.0    10.0   57369.61            1.0
# 9997        709.0    France  Female  36.0     7.0       0.00            1.0
# 9998        772.0   Germany    Male  42.0     3.0   75075.31            2.0
# 9999        792.0    France  Female  28.0     4.0  130142.79            1.0
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0           1.0             1.0        101348.88     1.0
# 1           0.0             1.0        112542.58     0.0
# 2           1.0             0.0        113931.57     1.0
# 3           0.0             0.0         93826.63     0.0
# 4           1.0             1.0         79084.10     0.0
# ...         ...             ...              ...     ...
# 9995        1.0             0.0         96270.64     0.0
# 9996        1.0             1.0        101699.77     0.0
# 9997        0.0             1.0         42085.58     1.0
# 9998        1.0             0.0         92888.52     1.0
# 9999        1.0             0.0         38190.78     0.0
#
# [10000 rows x 11 columns]

# %%
df.dtypes
# Out:
# CreditScore        float64
# Geography           object
# Gender              object
# Age                float64
# Tenure             float64
# Balance            float64
# NumOfProducts      float64
# HasCrCard          float64
# IsActiveMember     float64
# EstimatedSalary    float64
# Exited             float64
# dtype: object

# %%
numerical= df.drop(['Exited'], axis=1).select_dtypes('number').columns

categorical = df.select_dtypes('object').columns

# %%
df[numerical].head().T
# Out:
#                          0          1          2         3          4
# CreditScore         619.00     608.00     502.00    699.00     850.00
# Age                  42.00      41.00      42.00     39.00      43.00
# Tenure                2.00       1.00       8.00      1.00       2.00
# Balance               0.00   83807.86  159660.80      0.00  125510.82
# NumOfProducts         1.00       1.00       3.00      2.00       1.00
# HasCrCard             1.00       0.00       1.00      0.00       1.00
# IsActiveMember        1.00       1.00       0.00      0.00       1.00
# EstimatedSalary  101348.88  112542.58  113931.57  93826.63   79084.10

# %%
df[numerical].describe().T
# Out:
#                    count           mean           std     min       25%  \
# CreditScore      10000.0     650.528800     96.653299  350.00    584.00
# Age              10000.0      38.921800     10.487806   18.00     32.00
# Tenure           10000.0       5.012800      2.892174    0.00      3.00
# Balance          10000.0   76485.889288  62397.405202    0.00      0.00
# NumOfProducts    10000.0       1.530200      0.581654    1.00      1.00
# HasCrCard        10000.0       0.705500      0.455840    0.00      0.00
# IsActiveMember   10000.0       0.515100      0.499797    0.00      0.00
# EstimatedSalary  10000.0  100090.239881  57510.492818   11.58  51002.11
#
#                         50%          75%        max
# CreditScore         652.000     718.0000     850.00
# Age                  37.000      44.0000      92.00
# Tenure                5.000       7.0000      10.00
# Balance           97198.540  127644.2400  250898.09
# NumOfProducts         1.000       2.0000       4.00
# HasCrCard             1.000       1.0000       1.00
# IsActiveMember        1.000       1.0000       1.00
# EstimatedSalary  100193.915  149388.2475  199992.48

# %%
df[numerical].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df[numerical].plot(kind='hist', subplots=True, bins=50)
# Out:
# array([<AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>,
#        <AxesSubplot:ylabel='Frequency'>, <AxesSubplot:ylabel='Frequency'>],
#       dtype=object)

# %%
df["HasCrCard"].value_counts()
# Out:
# 1.0    7055
# 0.0    2945
# Name: HasCrCard, dtype: int64

# %%
df["IsActiveMember"].value_counts()
# Out:
# 1.0    5151
# 0.0    4849
# Name: IsActiveMember, dtype: int64

# %%
index = 0
plt.figure(figsize=(20,20))
for feature in numerical:
    if feature != "Exited":
        index += 1
        plt.subplot(4, 3, index)
        sns.boxplot(x='Exited', y=feature, data=df)

# %%
sns.pairplot(df, hue="Exited", palette="inferno", corner=True)

# %%
df[categorical].head().T
# Out:
#                 0       1       2       3       4
# Geography  France   Spain  France  France   Spain
# Gender     Female  Female  Female  Female  Female

# %%
df[categorical].describe().T.style.background_gradient(subset=['unique','freq','count'], cmap='RdPu')
# Out:
# <style type="text/css">
# #T_66337_row0_col0, #T_66337_row0_col3, #T_66337_row1_col0, #T_66337_row1_col1 {
#   background-color: #fff7f3;
#   color: #000000;
# }
# #T_66337_row0_col1, #T_66337_row1_col3 {
#   background-color: #49006a;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_66337_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >unique</th>
#       <th class="col_heading level0 col2" >top</th>
#       <th class="col_heading level0 col3" >freq</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_66337_level0_row0" class="row_heading level0 row0" >Geography</th>
#       <td id="T_66337_row0_col0" class="data row0 col0" >10000</td>
#       <td id="T_66337_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_66337_row0_col2" class="data row0 col2" >France</td>
#       <td id="T_66337_row0_col3" class="data row0 col3" >5014</td>
#     </tr>
#     <tr>
#       <th id="T_66337_level0_row1" class="row_heading level0 row1" >Gender</th>
#       <td id="T_66337_row1_col0" class="data row1 col0" >10000</td>
#       <td id="T_66337_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_66337_row1_col2" class="data row1 col2" >Male</td>
#       <td id="T_66337_row1_col3" class="data row1 col3" >5457</td>
#     </tr>
#   </tbody>
# </table>

# %%
df[categorical].nunique()
# Out:
# Geography    3
# Gender       2
# dtype: int64

# %%
for i, col in enumerate(df[categorical].columns):
    xtab = pd.crosstab(df[col], df['Exited'], normalize=True)
    print('-'*50, sep='')
    print(xtab*100)
# Out:
# --------------------------------------------------
# Exited       0.0   1.0
# Geography
# France     42.04  8.10
# Germany    16.95  8.14
# Spain      20.64  4.13
# --------------------------------------------------
# Exited    0.0    1.0
# Gender
# Female  34.04  11.39
# Male    45.59   8.98

# %%
df = pd.get_dummies(df, columns=['Geography', 'Gender'], drop_first=True)

# %%
plt.figure(figsize=(14, 10))
matrix = np.triu(df.corr())
sns.heatmap(df.corr(), annot=True, cmap = sns.cubehelix_palette(8), mask=matrix)
plt.xticks(rotation=45)
# Out:
# (array([ 0.5,  1.5,  2.5,  3.5,  4.5,  5.5,  6.5,  7.5,  8.5,  9.5, 10.5,
#         11.5]),
#  [Text(0.5, 0, 'CreditScore'),
#   Text(1.5, 0, 'Age'),
#   Text(2.5, 0, 'Tenure'),
#   Text(3.5, 0, 'Balance'),
#   Text(4.5, 0, 'NumOfProducts'),
#   Text(5.5, 0, 'HasCrCard'),
#   Text(6.5, 0, 'IsActiveMember'),
#   Text(7.5, 0, 'EstimatedSalary'),
#   Text(8.5, 0, 'Exited'),
#   Text(9.5, 0, 'Geography_Germany'),
#   Text(10.5, 0, 'Geography_Spain'),
#   Text(11.5, 0, 'Gender_Male')])

# %%
df.describe().T.style.background_gradient(subset=['mean','std','50%','count'], cmap='RdPu').format('{:.2f}')
# Out:
# <style type="text/css">
# #T_c7f2c_row0_col0, #T_c7f2c_row0_col2, #T_c7f2c_row1_col0, #T_c7f2c_row1_col1, #T_c7f2c_row1_col2, #T_c7f2c_row1_col5, #T_c7f2c_row2_col0, #T_c7f2c_row2_col1, #T_c7f2c_row2_col2, #T_c7f2c_row2_col5, #T_c7f2c_row3_col0, #T_c7f2c_row4_col0, #T_c7f2c_row4_col1, #T_c7f2c_row4_col2, #T_c7f2c_row4_col5, #T_c7f2c_row5_col0, #T_c7f2c_row5_col1, #T_c7f2c_row5_col2, #T_c7f2c_row5_col5, #T_c7f2c_row6_col0, #T_c7f2c_row6_col1, #T_c7f2c_row6_col2, #T_c7f2c_row6_col5, #T_c7f2c_row7_col0, #T_c7f2c_row8_col0, #T_c7f2c_row8_col1, #T_c7f2c_row8_col2, #T_c7f2c_row8_col5, #T_c7f2c_row9_col0, #T_c7f2c_row9_col1, #T_c7f2c_row9_col2, #T_c7f2c_row9_col5, #T_c7f2c_row10_col0, #T_c7f2c_row10_col1, #T_c7f2c_row10_col2, #T_c7f2c_row10_col5, #T_c7f2c_row11_col0, #T_c7f2c_row11_col1, #T_c7f2c_row11_col2, #T_c7f2c_row11_col5 {
#   background-color: #fff7f3;
#   color: #000000;
# }
# #T_c7f2c_row0_col1, #T_c7f2c_row0_col5 {
#   background-color: #fff6f2;
#   color: #000000;
# }
# #T_c7f2c_row3_col1 {
#   background-color: #a8017d;
#   color: #f1f1f1;
# }
# #T_c7f2c_row3_col2, #T_c7f2c_row7_col1, #T_c7f2c_row7_col5 {
#   background-color: #49006a;
#   color: #f1f1f1;
# }
# #T_c7f2c_row3_col5 {
#   background-color: #54006d;
#   color: #f1f1f1;
# }
# #T_c7f2c_row7_col2 {
#   background-color: #680172;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c7f2c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >count</th>
#       <th class="col_heading level0 col1" >mean</th>
#       <th class="col_heading level0 col2" >std</th>
#       <th class="col_heading level0 col3" >min</th>
#       <th class="col_heading level0 col4" >25%</th>
#       <th class="col_heading level0 col5" >50%</th>
#       <th class="col_heading level0 col6" >75%</th>
#       <th class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7f2c_level0_row0" class="row_heading level0 row0" >CreditScore</th>
#       <td id="T_c7f2c_row0_col0" class="data row0 col0" >10000.00</td>
#       <td id="T_c7f2c_row0_col1" class="data row0 col1" >650.53</td>
#       <td id="T_c7f2c_row0_col2" class="data row0 col2" >96.65</td>
#       <td id="T_c7f2c_row0_col3" class="data row0 col3" >350.00</td>
#       <td id="T_c7f2c_row0_col4" class="data row0 col4" >584.00</td>
#       <td id="T_c7f2c_row0_col5" class="data row0 col5" >652.00</td>
#       <td id="T_c7f2c_row0_col6" class="data row0 col6" >718.00</td>
#       <td id="T_c7f2c_row0_col7" class="data row0 col7" >850.00</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row1" class="row_heading level0 row1" >Age</th>
#       <td id="T_c7f2c_row1_col0" class="data row1 col0" >10000.00</td>
#       <td id="T_c7f2c_row1_col1" class="data row1 col1" >38.92</td>
#       <td id="T_c7f2c_row1_col2" class="data row1 col2" >10.49</td>
#       <td id="T_c7f2c_row1_col3" class="data row1 col3" >18.00</td>
#       <td id="T_c7f2c_row1_col4" class="data row1 col4" >32.00</td>
#       <td id="T_c7f2c_row1_col5" class="data row1 col5" >37.00</td>
#       <td id="T_c7f2c_row1_col6" class="data row1 col6" >44.00</td>
#       <td id="T_c7f2c_row1_col7" class="data row1 col7" >92.00</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row2" class="row_heading level0 row2" >Tenure</th>
#       <td id="T_c7f2c_row2_col0" class="data row2 col0" >10000.00</td>
#       <td id="T_c7f2c_row2_col1" class="data row2 col1" >5.01</td>
#       <td id="T_c7f2c_row2_col2" class="data row2 col2" >2.89</td>
#       <td id="T_c7f2c_row2_col3" class="data row2 col3" >0.00</td>
#       <td id="T_c7f2c_row2_col4" class="data row2 col4" >3.00</td>
#       <td id="T_c7f2c_row2_col5" class="data row2 col5" >5.00</td>
#       <td id="T_c7f2c_row2_col6" class="data row2 col6" >7.00</td>
#       <td id="T_c7f2c_row2_col7" class="data row2 col7" >10.00</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row3" class="row_heading level0 row3" >Balance</th>
#       <td id="T_c7f2c_row3_col0" class="data row3 col0" >10000.00</td>
#       <td id="T_c7f2c_row3_col1" class="data row3 col1" >76485.89</td>
#       <td id="T_c7f2c_row3_col2" class="data row3 col2" >62397.41</td>
#       <td id="T_c7f2c_row3_col3" class="data row3 col3" >0.00</td>
#       <td id="T_c7f2c_row3_col4" class="data row3 col4" >0.00</td>
#       <td id="T_c7f2c_row3_col5" class="data row3 col5" >97198.54</td>
#       <td id="T_c7f2c_row3_col6" class="data row3 col6" >127644.24</td>
#       <td id="T_c7f2c_row3_col7" class="data row3 col7" >250898.09</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row4" class="row_heading level0 row4" >NumOfProducts</th>
#       <td id="T_c7f2c_row4_col0" class="data row4 col0" >10000.00</td>
#       <td id="T_c7f2c_row4_col1" class="data row4 col1" >1.53</td>
#       <td id="T_c7f2c_row4_col2" class="data row4 col2" >0.58</td>
#       <td id="T_c7f2c_row4_col3" class="data row4 col3" >1.00</td>
#       <td id="T_c7f2c_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_c7f2c_row4_col5" class="data row4 col5" >1.00</td>
#       <td id="T_c7f2c_row4_col6" class="data row4 col6" >2.00</td>
#       <td id="T_c7f2c_row4_col7" class="data row4 col7" >4.00</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row5" class="row_heading level0 row5" >HasCrCard</th>
#       <td id="T_c7f2c_row5_col0" class="data row5 col0" >10000.00</td>
#       <td id="T_c7f2c_row5_col1" class="data row5 col1" >0.71</td>
#       <td id="T_c7f2c_row5_col2" class="data row5 col2" >0.46</td>
#       <td id="T_c7f2c_row5_col3" class="data row5 col3" >0.00</td>
#       <td id="T_c7f2c_row5_col4" class="data row5 col4" >0.00</td>
#       <td id="T_c7f2c_row5_col5" class="data row5 col5" >1.00</td>
#       <td id="T_c7f2c_row5_col6" class="data row5 col6" >1.00</td>
#       <td id="T_c7f2c_row5_col7" class="data row5 col7" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row6" class="row_heading level0 row6" >IsActiveMember</th>
#       <td id="T_c7f2c_row6_col0" class="data row6 col0" >10000.00</td>
#       <td id="T_c7f2c_row6_col1" class="data row6 col1" >0.52</td>
#       <td id="T_c7f2c_row6_col2" class="data row6 col2" >0.50</td>
#       <td id="T_c7f2c_row6_col3" class="data row6 col3" >0.00</td>
#       <td id="T_c7f2c_row6_col4" class="data row6 col4" >0.00</td>
#       <td id="T_c7f2c_row6_col5" class="data row6 col5" >1.00</td>
#       <td id="T_c7f2c_row6_col6" class="data row6 col6" >1.00</td>
#       <td id="T_c7f2c_row6_col7" class="data row6 col7" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row7" class="row_heading level0 row7" >EstimatedSalary</th>
#       <td id="T_c7f2c_row7_col0" class="data row7 col0" >10000.00</td>
#       <td id="T_c7f2c_row7_col1" class="data row7 col1" >100090.24</td>
#       <td id="T_c7f2c_row7_col2" class="data row7 col2" >57510.49</td>
#       <td id="T_c7f2c_row7_col3" class="data row7 col3" >11.58</td>
#       <td id="T_c7f2c_row7_col4" class="data row7 col4" >51002.11</td>
#       <td id="T_c7f2c_row7_col5" class="data row7 col5" >100193.91</td>
#       <td id="T_c7f2c_row7_col6" class="data row7 col6" >149388.25</td>
#       <td id="T_c7f2c_row7_col7" class="data row7 col7" >199992.48</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row8" class="row_heading level0 row8" >Exited</th>
#       <td id="T_c7f2c_row8_col0" class="data row8 col0" >10000.00</td>
#       <td id="T_c7f2c_row8_col1" class="data row8 col1" >0.20</td>
#       <td id="T_c7f2c_row8_col2" class="data row8 col2" >0.40</td>
#       <td id="T_c7f2c_row8_col3" class="data row8 col3" >0.00</td>
#       <td id="T_c7f2c_row8_col4" class="data row8 col4" >0.00</td>
#       <td id="T_c7f2c_row8_col5" class="data row8 col5" >0.00</td>
#       <td id="T_c7f2c_row8_col6" class="data row8 col6" >0.00</td>
#       <td id="T_c7f2c_row8_col7" class="data row8 col7" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_c7f2c_level0_row9" class="row_heading level0 row9" >Geography_Germany</th>
#       <td id="T_c7f2c_row9_col0" class="data row9 col0" >10000.00</td>
#       <td id="T_c7f2c_row9_col1" class="data row9 col1" >0.25</td>
#       <td id="T_c7f2c_row9_col2" class="data row9 col2" >0.43</td>

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

# %%
df.insert(12, 'churn', df['Exited'])

# %%
df.drop('Exited', axis=1, inplace=True)

# %%
X = df.drop('churn', axis=1)
y = df['churn'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y, test_size = 0.10, random_state = 42)
